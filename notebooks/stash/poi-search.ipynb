# %%
from pathlib import Path
import sys
import xml.etree.ElementTree as ET

import arcpy
import pandas as pd

project_parent = Path('./').absolute().parent.parent

# import the project package from the project package path
# ideally will be imported using 'from arcgis import dm'
sys.path.append(str(project_parent/'src'))
import dm

# load the "autoreload" extension so as src code is changed, the changes are picked up in the dataframe
# %load_ext autoreload
# %autoreload 2
# Out:
# D:\projects\demographic-modeling-module\src\dm\_modify_geoaccessor.py:31: UserWarning: registration of accessor <class 'dm._modify_geoaccessor.GeoAccessorIO'> under name 'spatial' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexistingattribute with the same name.
#   class GeoAccessorIO(GeoAccessor):

# %%
usa = dm.Country('USA')
aoi_df = usa.cbsas.get('seattle')
aoi_df.spatial.plot()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-75580d17-0e60-4be7-9d93-a930c7660e43"><img src=""></img></div>

# %%
biz_df = usa.business.get_by_name('Ace Hardware', aoi_df)
biz_df.head()
# Out:
#    OBJECTID     LOCNUM                    CONAME               STREET  \
# 0   1742102  371889957       GRAHAM ACE HARDWARE           224TH ST E
# 1   5853272  460556608     OAKBROOK ACE HARDWARE   STEILACOOM BLVD SW
# 2   2830418  405129289   GIG HARBOR ACE HARDWARE  POINT FOSDICK DR NW
# 3   2690144  404324160     AGRISHOP ACE HARDWARE            S 12TH ST
# 4   2215877  401684669  ACE HARDWARE & PAINT CTR           N PEARL ST
#
#          CITY STATE  STATE_NAME    ZIP  ZIP4     NAICS  ... EMPNUM  FRNCOD  \
# 0      GRAHAM    WA  Washington  98338  5704  44413005  ...   15.0       1
# 1    LAKEWOOD    WA  Washington  98498  6154  44413005  ...    9.0       1
# 2  GIG HARBOR    WA  Washington  98335  1711  44413005  ...   38.0       1
# 3      TACOMA    WA  Washington  98405  3004  44413005  ...   10.0       1
# 4      TACOMA    WA  Washington  98407  2416  44413005  ...   23.0       1
#
#   ISCODE SQFTCODE       LOC_NAME  STATUS  SCORE     SOURCE REC_TYPE  \
# 0               5   PointAddress       M  100.0  INFOGROUP        0
# 1               3  StreetAddress       M  100.0  INFOGROUP        0
# 2               7  StreetAddress       M  100.0  INFOGROUP        0
# 3               5   PointAddress       M  100.0  INFOGROUP        0
# 4               8   PointAddress       M  100.0  INFOGROUP        0
#
#                                                SHAPE
# 0  {"x": -13614273.536475636, "y": 5950909.044418...
# 1  {"x": -13641713.790956184, "y": 5971504.304607...
# 2  {"x": -13645465.257795917, "y": 5991409.736829...
# 3  {"x": -13632607.856609292, "y": 5982959.933531...
# 4  {"x": -13638162.699199878, "y": 5986847.462380...
#
# [5 rows x 25 columns]

# %%
biz_df.spatial.plot()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b9e41c0d-c6b8-44e2-8838-9e96bf45899f"><img src=""></img></div>

# %%
comp_df = usa.business.get_competition('Ace Hardware', aoi_df)
comp_df.head()
# Out:
#    OBJECTID     LOCNUM                        CONAME             STREET  \
# 0  11948738  740405810    CASCADE WHOLESALE HARDWARE     PACIFIC HWY SW
# 1    791119  175096239     LAKEWOOD HARDWARE & PAINT     LAKEWOOD DR SW
# 2   9459298  717157403               SWINGS & THINGS  BRIDGEPORT WAY SW
# 3   9417066  716987694  WILCO FARM STORES-GIG HARBOR       E HIGHWAY 20
# 4   4190467  425066759         MCLENDON HARDWARE INC         N PEARL ST
#
#          CITY STATE  STATE_NAME    ZIP  ZIP4     NAICS  ... EMPNUM  FRNCOD  \
# 0    LAKEWOOD    WA  Washington  98499  1027  44413005  ...    6.0
# 1    LAKEWOOD    WA  Washington  98499  3966  44413005  ...   15.0       B
# 2    LAKEWOOD    WA  Washington  98499  2645  44413005  ...    1.0
# 3  GIG HARBOR    WA  Washington  98335        44413005  ...    6.0
# 4      TACOMA    WA  Washington  98406  7921  44413005  ...   38.0
#
#   ISCODE SQFTCODE      LOC_NAME  STATUS  SCORE     SOURCE REC_TYPE  \
# 0               3  PointAddress       M  100.0  INFOGROUP        0
# 1               5  PointAddress       M  100.0  INFOGROUP        0
# 2               1  PointAddress       M  100.0  INFOGROUP        0
# 3               3        Postal       M  100.0  INFOGROUP        0
# 4               7  PointAddress       M  100.0  INFOGROUP        0
#
#                                                SHAPE
# 0  {"x": -13638463.261825016, "y": 5965397.528925...
# 1  {"x": -13637583.837847747, "y": 5970734.581986...
# 2  {"x": -13638585.713264894, "y": 5970980.230739...
# 3  {"x": -13645476.389744991, "y": 5992394.715097...
# 4  {"x": -13638251.754792504, "y": 5984485.212081...
#
# [5 rows x 25 columns]

# %%
comp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    93 non-null     int64
#  1   LOCNUM      93 non-null     object
#  2   CONAME      93 non-null     object
#  3   STREET      93 non-null     object
#  4   CITY        93 non-null     object
#  5   STATE       93 non-null     object
#  6   STATE_NAME  93 non-null     object
#  7   ZIP         93 non-null     object
#  8   ZIP4        93 non-null     object
#  9   NAICS       93 non-null     object
#  10  SIC         93 non-null     object
#  11  SALESVOL    93 non-null     float64
#  12  HDBRCH      93 non-null     object
#  13  ULTNUM      93 non-null     object
#  14  PUBPRV      93 non-null     object
#  15  EMPNUM      93 non-null     float64
#  16  FRNCOD      93 non-null     object
#  17  ISCODE      93 non-null     object
#  18  SQFTCODE    93 non-null     object
#  19  LOC_NAME    93 non-null     object
#  20  STATUS      93 non-null     object
#  21  SCORE       93 non-null     float64
#  22  SOURCE      93 non-null     object
#  23  REC_TYPE    93 non-null     int64
#  24  SHAPE       93 non-null     geometry
# dtypes: float64(3), geometry(1), int64(2), object(19)
# memory usage: 18.3+ KB
