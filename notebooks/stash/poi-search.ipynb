# %%
from pathlib import Path
import sys
import xml.etree.ElementTree as ET

import arcpy
import pandas as pd

project_parent = Path('./').absolute().parent.parent

# import the project package from the project package path
# ideally will be imported using 'from arcgis import dm'
sys.path.append(str(project_parent/'src'))
import dm

# load the "autoreload" extension so as src code is changed, the changes are picked up in the dataframe
# %load_ext autoreload
# %autoreload 2
# Out:
# D:\projects\demographic-modeling-module\src\dm\_modify_geoaccessor.py:32: UserWarning: registration of accessor <class 'dm._modify_geoaccessor.GeoAccessorIO'> under name 'spatial' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexistingattribute with the same name.
#   class GeoAccessorIO(GeoAccessor):

# %%
can = dm.Country('CAN')

can
# Out:
# <dm.Country - CAN (local)>

# %%
aoi_df = can.cmacas.get('Vancouver')

aoi_df.spatial.plot()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-663f6e82-b3bd-4f4e-b2d6-dab583bbe868"><img src=""></img></div>

# %%
biz_df = can.business.get_by_name('Canadian Tire', aoi_df)

biz_df.head()
# Out:
#    OBJECTID     LOCNUM         CONAME      STREET  FSA        CITY PROV  \
# 0   1082512  734334237  Canadian Tire  Canoe Pass  V4M  Tsawwassen   BC
# 1    550834  437319782  Canadian Tire       No. 3  V6X    Richmond   BC
# 2    429124   36617447  Canadian Tire   Steveston  V7E    Richmond   BC
# 3    942986   61704763  Canadian Tire     Ontario  V5X   Vancouver   BC
# 4    744868   50805480  Canadian Tire      Market  V5J     Burnaby   BC
#
#           PROV_NAME   POSTCD     NAICS  ... FRNCOD ISCODE       LOC_NAME  \
# 0  British Columbia  V4M 0B2  45221001  ...      A         StreetAddress
# 1  British Columbia  V6X 2C1  45221001  ...      A         StreetAddress
# 2  British Columbia  V7A 5J5  45221001  ...      A          PointAddress
# 3  British Columbia  V5X 0A7  45221001  ...      A         StreetAddress
# 4  British Columbia  V5J 0A2  45221001  ...      A         StreetAddress
#
#   STATUS   SCORE     SOURCE  \
# 0      M   95.76  INFOGROUP
# 1      M  100.00  INFOGROUP
# ...

# %%
biz_df.spatial.plot()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-d03099e6-b1ad-4311-b55b-d52d23534f10"><img src=""></img></div>

# %%
naics_df = can.business.get_by_code(452210, aoi_df)

naics_df.head()
# Out:
#    OBJECTID     LOCNUM                          CONAME      STREET  FSA  \
# 0    633784  440546527             Walmart Supercenter  Canoe Pass  V4M
# 1   1082512  734334237                   Canadian Tire  Canoe Pass  V4M
# 2   1087336  736053136  Laura-Laura Petites-Laura Plus  Canoe Pass  V4M
# 3    322144   28839553               Loonie Town Store       No. 2  V7C
# 4    198887   20023503                    HUDSON'S BAY      Minoru  V6Y
#
#          CITY PROV         PROV_NAME   POSTCD     NAICS  ... FRNCOD ISCODE  \
# 0  Tsawwassen   BC  British Columbia  V4M 0B2  45221001  ...      m
# 1  Tsawwassen   BC  British Columbia  V4M 0B2  45221001  ...      A
# 2  Tsawwassen   BC  British Columbia  V4M 0B3  45221003  ...
# 3    Richmond   BC  British Columbia  V7C 5K1  45221003  ...
# 4    Richmond   BC  British Columbia  V6Y 1Y2  45221001  ...      8
#
#         LOC_NAME STATUS   SCORE     SOURCE  \
# 0  StreetAddress      M   95.76  INFOGROUP
# ...

# %%
comp_df = can.business.get_competition(biz_df, aoi_df)
comp_df.head()
# Out:
#    OBJECTID     LOCNUM               CONAME      STREET  FSA        CITY PROV  \
# 0    633784  440546527  Walmart Supercenter  Canoe Pass  V4M  Tsawwassen   BC
# 1    198887   20023503         HUDSON'S BAY      Minoru  V6Y    Richmond   BC
# 2    322183   28842649           LE CHATEAU      Minoru  V6Y    Richmond   BC
# 3    956927   62206552                Roots       No. 3  V6Y    Richmond   BC
# 4   1089774  736729585  Thinka Creative Ltd        No 3  V6X    Richmond   BC
#
#           PROV_NAME   POSTCD     NAICS  ... FRNCOD ISCODE       LOC_NAME  \
# 0  British Columbia  V4M 0B2  45221001  ...      m         StreetAddress
# 1  British Columbia  V6Y 1Y2  45221001  ...      8         StreetAddress
# 2  British Columbia  V6Y 2V7  45221001  ...      l         StreetAddress
# 3  British Columbia  V6Y 2B6  45221001  ...      r         StreetAddress
# 4  British Columbia  V6X 2X9  45221001  ...                StreetAddress
#
#   STATUS   SCORE     SOURCE  \
# ...

# %%
comp_df.spatial.plot()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-f9323b92-7cfe-4c2d-95bc-1c952b5cb760"><img src=""></img></div>
